# %% [markdown]
# # Determinig Top T20 Team Of Pakistan

# %%
import pandas as pd
import json
import os

# %%
#Reading the Json file containing Raw Data of Pakistani Players
folder_path = r"C:\Users\4A\Documents\projects\cricket project"

# %% [markdown]
# **Extracting the Json file contatinig T20 data Only**

# %%
T20_FILES = []
for file_name in os.listdir(folder_path):
    if file_name.endswith('.json'):
        file_path = os.path.join(folder_path, file_name)
        try:
            with open(file_path, 'r') as json_file:
                data = json.load(json_file)
            
            # Check the condition
            if data.get('info', {}).get('match_type') == 'T20':
                T20_FILES.append(file_name)
        except (json.JSONDecodeError, FileNotFoundError, KeyError) as e:
            print(f"Error processing {file_name}: {e}")

# Print the list of T20 files
print("T20_FILES:", len(T20_FILES))
# Out:
# T20_FILES: 243

# %%
match_information={ 
'city':[],
'event':[],
'stage':[],
'dates':[],
'match_type':[],
'match_type_number':[],
'winner':[],
'winner_by':[],
'overs':[],
'season':[],
'team_type':[],
'team1':[],
'team2':[],
'toss_winner':[],
'toss_decision':[],
'venue':[]
}

players_infomation={
    'name':[],
    'team':[],
    'match_type_number':[],
    'match_type':[],
    'venue':[]
}

# %%
def extract_match_info(rawdata):
    if 'city' in rawdata['info']:
        match_information['city'].append(rawdata['info']['city'])
    else:
        match_information['city'].append(None)
    if 'event' in rawdata['info']:
        match_information['event'].append(rawdata['info']['event']['name'])
        if 'stage' in rawdata['info']['event']:
            match_information['stage'].append(rawdata['info']['event']['stage'])
        else:
            match_information['stage'].append(None)
    else:
        match_information['event'].append(None)
        match_information['stage'].append(None)
        
    match_information['dates'].append(''.join(rawdata['info']['dates']))
    match_information['match_type'].append(rawdata['info']['match_type'])
    match_information['match_type_number'].append(rawdata['info']['match_type_number'])
    if 'winner' in rawdata['info']['outcome']:
        match_information['winner'].append(rawdata['info']['outcome']['winner'])
        match_information['winner_by'].append(rawdata['info']['outcome']['by'])
    else:
        match_information['winner'].append('no result')
        match_information['winner_by'].append('no result')
    match_information['overs'].append(rawdata['info']['overs'])
    match_information['season'].append(rawdata['info']['season'])
    match_information['team_type'].append(rawdata['info']['team_type'])
    match_information['team1'].append(rawdata['info']['teams'][0])
    match_information['team2'].append(rawdata['info']['teams'][1])
    match_information['toss_winner'].append(rawdata['info']['toss']['winner'])
    match_information['toss_decision'].append(rawdata['info']['toss']['decision'])
    match_information['venue'].append(rawdata['info']['venue'])
    
def players_info(rawdata):
    for x in rawdata['info']['players']:
        for y in rawdata['info']['players'][x]:
            players_infomation['name'].append(y)
            players_infomation['match_type_number'].append(rawdata['info']['match_type_number'])
            players_infomation['match_type'].append(rawdata['info']['match_type'])
            players_infomation['team'].append(x)
            players_infomation['venue'].append(rawdata['info']['venue'])

# %%
def innings_data(raw_data):
    innings_data = raw_data['innings']
    rows = []
    for inning in innings_data:
        team = inning['team']
        for over in inning['overs']:
            over_number = over['over']
            for delivery in over['deliveries']:
                row = {
                    'Team': team,
                    'Over': over_number,
                    'Batter': delivery['batter'],
                    'Bowler': delivery['bowler'],
                    'Non_Striker': delivery.get('non_striker', None),
                    'Runs_Batter': delivery['runs']['batter'],
                    'Runs_Extras': delivery['runs'].get('extras', 0),
                    'Runs_Total': delivery['runs']['total']
                }
                if 'wickets' in delivery:
                    row['Wickets']  = 1
                    row['player_out'] = delivery['wickets'][0]['player_out']
                    if 'fielders' in delivery['wickets'][0]:
                        row['fielder_name'] = delivery['wickets'][0]['fielders'][0]['name']
                    else:
                         row['fielder_name'] = None
                    row['kind']= delivery['wickets'][0]['kind']
                else:
                    row['Wickets'] = 0
                    row['fielder_name'] = None
                    row['kind'] = None
                
                rows.append(row)
    return pd.DataFrame(rows)

# %% [markdown]
# **Extracting Mathces Information From Json File**

# %%
for name in T20_FILES:
    print(name) 
    with open(r'C:\Users\4A\Documents\projects\cricket project'+"\\"+ name) as file:
        rawdata = json.load(file)
        extract_match_info(rawdata)
# Out:
# 1050217.json
# 1050219.json
# 1050221.json
# 1077947.json
# 1077948.json
# 1085495.json
# 1085496.json
# 1115807.json
# 1115808.json
# 1115809.json
# 1117821.json
# 1117822.json
# 1117824.json
# 1120291.json
# 1120292.json
# 1120293.json
# 1127300.json
# 1127301.json
# 1140069.json
# 1140070.json
# 1140071.json
# 1142913.json
# 1142914.json
# 1142916.json
# 1142917.json
# 1142919.json
# 1144161.json
# 1144162.json
# 1144163.json
# 1152840.json
# 1157372.json
# 1157373.json
# 1157374.json
# 1157375.json
# 1157376.json
# 1157377.json
# 1183527.json
# 1183528.json
# 1183529.json
# 1198244.json
# 1198245.json
# 1198246.json
# 1198489.json
# 1198490.json
# 1198491.json
# 1213058.json
# 1213059.json
# 1233464.json
# 1233465.json
# 1233466.json
# 1233959.json
# 1233960.json
# 1233961.json
# 1239540.json
# 1239541.json
# 1239542.json
# 1243019.json
# 1243020.json
# 1243021.json
# 1251575.json
# 1251576.json
# 1251577.json
# 1251578.json
# 1257183.json
# 1257184.json
# 1257185.json
# 1263164.json
# 1263165.json
# 1263166.json
# 1263167.json
# 1273727.json
# 1273730.json
# 1273742.json
# 1273752.json
# 1273755.json
# 1277974.json
# 1277975.json
# 1277976.json
# 1287773.json
# 1287774.json
# 1287775.json
# 1288316.json
# 1298150.json
# 1298158.json
# 1298163.json
# 1298170.json
# 1298175.json
# 1298177.json
# 1298179.json
# 1322334.json
# 1322335.json
# 1322337.json
# 1322339.json
# 1322340.json
# 1327228.json
# 1327229.json
# 1327230.json
# 1327231.json
# 1327232.json
# 1327233.json
# 1327234.json
# 1327270.json
# 1327274.json
# 1327276.json
# 1327280.json
# 1327281.json
# 1339614.json
# 1339615.json
# 1339616.json
# 1339617.json
# 1339618.json
# 1385688.json
# 1385690.json
# 1388216.json
# 1388217.json
# 1388218.json
# 1388219.json
# 1388220.json
# 1399114.json
# 1399119.json
# 1415711.json
# 1415719.json
# 1415722.json
# 1415736.json
# 1424829.json
# 1424830.json
# 1424831.json
# 1424832.json
# 1424833.json
# 1426552.json
# 1426553.json
# 1426554.json
# 1426830.json
# 1426831.json
# 1426832.json
# 1432211.json
# 589307.json
# 645645.json
# 645647.json
# 649101.json
# 649103.json
# 657633.json
# 657635.json
# 659545.json
# 659547.json
# 682921.json
# 682927.json
# 682949.json
# 682959.json
# 685727.json
# 685729.json
# 727917.json
# 742617.json
# 754039.json
# 858491.json
# 860279.json
# 860281.json
# 868723.json
# 868725.json
# 902649.json
# 902651.json
# 902653.json
# 913663.json
# 914221.json
# 914223.json
# 914225.json
# 919603.json
# 919605.json
# 951333.json
# 951341.json
# 951349.json
# 951355.json
# 966751.json
# 966755.json
# 966759.json
# 966763.json

# %%
for x,y in match_information.items():
    print(f'{x}: length {len(y)}')
# Out:
# city: length 243
# event: length 243
# stage: length 243
# dates: length 243
# match_type: length 243
# match_type_number: length 243
# winner: length 243
# winner_by: length 243
# overs: length 243
# season: length 243
# team_type: length 243
# team1: length 243
# team2: length 243
# toss_winner: length 243
# toss_decision: length 243
# venue: length 243

# %% [markdown]
# # **Take a Look at Extracted Information**

# %%
pd.DataFrame(match_information)
# Out:
#            city                                event     stage       dates  \
# 0          None   Pakistan v West Indies T20I Series      None  2016-09-23
# 1          None   Pakistan v West Indies T20I Series      None  2016-09-24
# 2     Abu Dhabi   Pakistan v West Indies T20I Series      None  2016-09-27
# 3      Barbados  Pakistan in West Indies T20I Series      None  2017-03-26
# 4      Trinidad  Pakistan in West Indies T20I Series      None  2017-03-30
# ..          ...                                  ...       ...         ...
# 238  Chandigarh                            World T20  Super 10  2016-03-25
# 239      Mirpur                             Asia Cup      None  2016-02-27
# 240      Mirpur                             Asia Cup      None  2016-02-29
# 241      Mirpur                             Asia Cup      None  2016-03-02
# 242      Mirpur                             Asia Cup      None  2016-03-04
#
#     match_type  match_type_number      winner       winner_by  overs   season  \
# 0          T20                568    Pakistan  {'wickets': 9}     20  2016/17
# 1          T20                569    Pakistan    {'runs': 16}     20  2016/17
# 2          T20                570    Pakistan  {'wickets': 8}     20  2016/17
# 3          T20                602    Pakistan  {'wickets': 6}     20     2017
# 4          T20                603    Pakistan     {'runs': 3}     20     2017
# ..         ...                ...         ...             ...    ...      ...
# 238        T20                548   Australia    {'runs': 21}     20  2015/16
# 239        T20                512       India  {'wickets': 5}     20  2015/16
# 240        T20                514    Pakistan  {'wickets': 7}     20  2015/16
# 241        T20                516  Bangladesh  {'wickets': 5}     20  2015/16
# 242        T20                518    Pakistan  {'wickets': 6}     20  2015/16
#
#          team_type        team1                 team2           toss_winner  \
# 0    international     Pakistan           West Indies              Pakistan
# 1    international     Pakistan           West Indies           West Indies
# 2    international     Pakistan           West Indies              Pakistan
# 3    international  West Indies              Pakistan              Pakistan
# 4    international  West Indies              Pakistan           West Indies
# ..             ...          ...                   ...                   ...
# 238  international    Australia              Pakistan             Australia
# 239  international        India              Pakistan                 India
# 240  international     Pakistan  United Arab Emirates  United Arab Emirates
# 241  international   Bangladesh              Pakistan              Pakistan
# 242  international     Pakistan             Sri Lanka              Pakistan
#
#     toss_decision                                              venue
# 0           field                Dubai International Cricket Stadium
# 1           field                Dubai International Cricket Stadium
# 2           field                               Sheikh Zayed Stadium
# 3           field                        Kensington Oval, Bridgetown
# 4           field                   Queen's Park Oval, Port of Spain
# ..            ...                                                ...
# 238           bat  Punjab Cricket Association IS Bindra Stadium, ...
# 239         field                      Shere Bangla National Stadium
# 240           bat                      Shere Bangla National Stadium
# 241           bat                      Shere Bangla National Stadium
# 242         field                      Shere Bangla National Stadium
#
# [243 rows x 16 columns]

# %%
pd.DataFrame(players_infomation)
# Out:
#                  name       team  match_type_number match_type  \
# 0       Sharjeel Khan   Pakistan                568        T20
# 1        Khalid Latif   Pakistan                568        T20
# 2          Babar Azam   Pakistan                568        T20
# 3        Shoaib Malik   Pakistan                568        T20
# 4          Umar Akmal   Pakistan                568        T20
# ...               ...        ...                ...        ...
# 5342      N Dickwella  Sri Lanka                518        T20
# 5343      NLTC Perera  Sri Lanka                518        T20
# 5344  KMDN Kulasekara  Sri Lanka                518        T20
# 5345     HMRKB Herath  Sri Lanka                518        T20
# 5346     PVD Chameera  Sri Lanka                518        T20
#
#                                     venue
# 0     Dubai International Cricket Stadium
# 1     Dubai International Cricket Stadium
# 2     Dubai International Cricket Stadium
# 3     Dubai International Cricket Stadium
# 4     Dubai International Cricket Stadium
# ...                                   ...
# 5342        Shere Bangla National Stadium
# 5343        Shere Bangla National Stadium
# 5344        Shere Bangla National Stadium
# 5345        Shere Bangla National Stadium
# 5346        Shere Bangla National Stadium
#
# [5347 rows x 5 columns]

# %%
import os
import pandas as pd

def contact_match_FILES(csvs_list):
    # Define the root directory path
    directory = r"C:\Users\4A\Documents\projects\.ipynb_checkpoints"
    
    # Ensure the directory exists
    if not os.path.exists(directory):
        print("The specified directory does not exist.")
        return
    
    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        # Filter out only CSV files and append their names to the list
        for file in files:
            if file.endswith('.csv'):
                # Append only the file name, not the full path
                csvs_list.append(file)
    
    # Output the final list of CSV files found
    print(f"Found {len(csvs_list)} CSV files:")

# %%
csvs_list = []
contact_match_FILES(csvs_list)
# Out:
# Found 243 CSV files:

# %%
# Fixing the CSV file extensions in the csvs_list
csvs_list = [file.replace('..csv', '.csv') for file in csvs_list]
csvs_list
# Out:
# ['Australia_vs_Pakistan_1142919.csv',
#  'Australia_vs_Pakistan_1183527.csv',
#  'Australia_vs_Pakistan_1183528.csv',
#  'Australia_vs_Pakistan_1183529.csv',
#  'Australia_vs_Pakistan_1426552.csv',
#  'Australia_vs_Pakistan_1426553.csv',
#  'Australia_vs_Pakistan_287870.csv',
#  'Australia_vs_Pakistan_392615.csv',
#  'Australia_vs_Pakistan_406207.csv',
#  'Australia_vs_Pakistan_412683.csv',
#  'Australia_vs_Pakistan_412702.csv',
#  'Australia_vs_Pakistan_426392.csv',
#  'Australia_vs_Pakistan_426393.csv',
#  'Australia_vs_Pakistan_533294.csv',
#  'Australia_vs_Pakistan_571148.csv',
#  'Australia_vs_Pakistan_571149.csv',
#  'Australia_vs_Pakistan_571150.csv',
#  'Australia_vs_Pakistan_682927.csv',
#  'Australia_vs_Pakistan_727917.csv',
#  'Australia_vs_Pakistan_951355.csv',
#  'Bangladesh_vs_Pakistan_1277974.csv',
#  'Bangladesh_vs_Pakistan_1277975.csv',
#  'Bangladesh_vs_Pakistan_1277976.csv',
#  'Bangladesh_vs_Pakistan_1298175.csv',
#  'Bangladesh_vs_Pakistan_1322339.csv',
#  'Bangladesh_vs_Pakistan_287875.csv',
#  'Bangladesh_vs_Pakistan_306989.csv',
#  'Bangladesh_vs_Pakistan_412680.csv',
#  'Bangladesh_vs_Pakistan_533283.csv',
#  'Bangladesh_vs_Pakistan_538068.csv',
#  'Bangladesh_vs_Pakistan_682949.csv',
#  'Bangladesh_vs_Pakistan_858491.csv',
#  'Bangladesh_vs_Pakistan_951333.csv',
#  'Bangladesh_vs_Pakistan_966759.csv',
#  'Canada_vs_Pakistan_1415722.csv',
#  'England_vs_Pakistan_1152840.csv',
#  'England_vs_Pakistan_1198244.csv',
#  'England_vs_Pakistan_1239541.csv',
#  'England_vs_Pakistan_1327229.csv',
#  'England_vs_Pakistan_1327230.csv',
#  'England_vs_Pakistan_1327234.csv',
#  'England_vs_Pakistan_1385688.csv',
#  'England_vs_Pakistan_225263.csv',
#  'England_vs_Pakistan_355996.csv',
#  'England_vs_Pakistan_412689.csv',
#  'England_vs_Pakistan_426417.csv',
#  'England_vs_Pakistan_426418.csv',
#  'England_vs_Pakistan_440945.csv',
#  'England_vs_Pakistan_440946.csv',
#  'England_vs_Pakistan_531635.csv',
#  'England_vs_Pakistan_531636.csv',
#  'England_vs_Pakistan_531637.csv',
#  'England_vs_Pakistan_902649.csv',
#  'England_vs_Pakistan_902651.csv',
#  'England_vs_Pakistan_902653.csv',
#  'England_vs_Pakistan_913663.csv',
#  'India_vs_Pakistan_1273727.csv',
#  'India_vs_Pakistan_1327276.csv',
#  'India_vs_Pakistan_1415719.csv',
#  'India_vs_Pakistan_287862.csv',
#  'India_vs_Pakistan_287879.csv',
#  'India_vs_Pakistan_533291.csv',
#  'India_vs_Pakistan_589306.csv',
#  'India_vs_Pakistan_589307.csv',
#  'India_vs_Pakistan_682921.csv',
#  'India_vs_Pakistan_951341.csv',
#  'India_vs_Pakistan_966751.csv',
#  'Ireland_vs_Pakistan_1415736.csv',
#  'Ireland_vs_Pakistan_1426831.csv',
#  'Ireland_vs_Pakistan_1426832.csv',
#  'Ireland_vs_Pakistan_356012.csv',
#  'Kenya_vs_Pakistan_306991.csv',
#  'Netherlands_vs_Pakistan_1298163.csv',
#  'Netherlands_vs_Pakistan_355999.csv',
#  'New Zealand_vs_Pakistan_1157376.csv',
#  'New Zealand_vs_Pakistan_1233961.csv',
#  'New Zealand_vs_Pakistan_1273730.csv',
#  'New Zealand_vs_Pakistan_1298177.csv',
#  'New Zealand_vs_Pakistan_1322335.csv',
#  'New Zealand_vs_Pakistan_1322340.csv',
#  'New Zealand_vs_Pakistan_1339616.csv',
#  'New Zealand_vs_Pakistan_1339617.csv',
#  'New Zealand_vs_Pakistan_1388216.csv',
#  'New Zealand_vs_Pakistan_1388217.csv',
#  'New Zealand_vs_Pakistan_1388218.csv',
#  'New Zealand_vs_Pakistan_1424829.csv',
#  'New Zealand_vs_Pakistan_1424830.csv',
#  'New Zealand_vs_Pakistan_1424832.csv',
#  'New Zealand_vs_Pakistan_287877.csv',
#  'New Zealand_vs_Pakistan_356008.csv',
#  'New Zealand_vs_Pakistan_412693.csv',
#  'New Zealand_vs_Pakistan_426723.csv',
#  'New Zealand_vs_Pakistan_426724.csv',
#  'New Zealand_vs_Pakistan_473918.csv',
#  'New Zealand_vs_Pakistan_473919.csv',
#  'New Zealand_vs_Pakistan_473920.csv',
#  'New Zealand_vs_Pakistan_533280.csv',
#  'New Zealand_vs_Pakistan_742617.csv',
#  'New Zealand_vs_Pakistan_754039.csv',
#  'New Zealand_vs_Pakistan_914221.csv',
#  'New Zealand_vs_Pakistan_914223.csv',
#  'New Zealand_vs_Pakistan_914225.csv',
#  'New Zealand_vs_Pakistan_951349.csv',
#  'Pakistan_vs_Australia_1142914.csv',
#  'Pakistan_vs_Australia_1142917.csv',
#  'Pakistan_vs_Australia_1157372.csv',
#  'Pakistan_vs_Australia_1157373.csv',
#  'Pakistan_vs_Australia_1157374.csv',
#  'Pakistan_vs_Australia_1273755.csv',
#  'Pakistan_vs_Australia_1288316.csv',
#  'Pakistan_vs_Australia_1426554.csv',
#  'Pakistan_vs_Bangladesh_1213058.csv',
#  'Pakistan_vs_Bangladesh_1213059.csv',
#  'Pakistan_vs_Bangladesh_1322334.csv',
#  'Pakistan_vs_Bangladesh_1399119.csv',
#  'Pakistan_vs_Bangladesh_343764.csv',
#  'Pakistan_vs_England_1198245.csv',
#  'Pakistan_vs_England_1198246.csv',
#  'Pakistan_vs_England_1239540.csv',
#  'Pakistan_vs_England_1239542.csv',
#  'Pakistan_vs_England_1298179.csv',
#  'Pakistan_vs_England_1327228.csv',
#  'Pakistan_vs_England_1327231.csv',
#  'Pakistan_vs_England_1327232.csv',
#  'Pakistan_vs_England_1327233.csv',
#  'Pakistan_vs_England_1385690.csv',
#  'Pakistan_vs_Hong Kong_1327274.csv',
#  'Pakistan_vs_Hong Kong_1399114.csv',
#  'Pakistan_vs_ICC World XI_1117821.csv',
#  'Pakistan_vs_ICC World XI_1117822.csv',
#  'Pakistan_vs_ICC World XI_1117824.csv',
#  'Pakistan_vs_India_1298150.csv',
#  'Pakistan_vs_India_1327270.csv',
#  'Pakistan_vs_Ireland_1426830.csv',
#  'Pakistan_vs_Namibia_1273742.csv',
#  'Pakistan_vs_New Zealand_1115807.csv',
#  'Pakistan_vs_New Zealand_1115808.csv',
#  'Pakistan_vs_New Zealand_1115809.csv',
#  'Pakistan_vs_New Zealand_1157375.csv',
#  'Pakistan_vs_New Zealand_1157377.csv',
#  'Pakistan_vs_Zimbabwe_868725.csv',
#  'South Africa_vs_Pakistan_1144161.csv',
#  'South Africa_vs_Pakistan_1144162.csv',
#  'South Africa_vs_Pakistan_1144163.csv',
#  'South Africa_vs_Pakistan_1243021.csv',
#  'South Africa_vs_Pakistan_1251575.csv',
#  'South Africa_vs_Pakistan_1251577.csv',
#  'South Africa_vs_Pakistan_1251578.csv',
#  'South Africa_vs_Pakistan_1432211.csv',
#  'South Africa_vs_Pakistan_567367.csv',
#  'South Africa_vs_Pakistan_685727.csv',
#  'South Africa_vs_Pakistan_685729.csv',
#  'Sri Lanka_vs_Pakistan_1120291.csv',
#  'Sri Lanka_vs_Pakistan_1120292.csv',
#  'Sri Lanka_vs_Pakistan_1327281.csv',
#  'Sri Lanka_vs_Pakistan_403375.csv',
#  'Sri Lanka_vs_Pakistan_533296.csv',
#  'Sri Lanka_vs_Pakistan_562437.csv',
#  'Sri Lanka_vs_Pakistan_562438.csv',
#  'Sri Lanka_vs_Pakistan_860279.csv',
#  'Sri Lanka_vs_Pakistan_860281.csv',
#  'West Indies_vs_Pakistan_1077947.csv',
#  'West Indies_vs_Pakistan_1077948.csv',
#  'West Indies_vs_Pakistan_1085495.csv',
#  'West Indies_vs_Pakistan_1085496.csv',
#  'West Indies_vs_Pakistan_1140071.csv',
#  'West Indies_vs_Pakistan_1263164.csv',
#  'West Indies_vs_Pakistan_1263166.csv',
#  'West Indies_vs_Pakistan_1263167.csv',
#  'West Indies_vs_Pakistan_1287775.csv',
#  'West Indies_vs_Pakistan_489212.csv',
#  'West Indies_vs_Pakistan_645645.csv',
#  'West Indies_vs_Pakistan_645647.csv',
#  'Zimbabwe_vs_Pakistan_1142916.csv',
#  'Zimbabwe_vs_Pakistan_1233464.csv',
#  'Zimbabwe_vs_Pakistan_1233465.csv',
#  'Zimbabwe_vs_Pakistan_1233466.csv',
#  'Zimbabwe_vs_Pakistan_1257184.csv',
#  'Zimbabwe_vs_Pakistan_1298158.csv',
#  'Zimbabwe_vs_Pakistan_1444653.csv',
#  'Zimbabwe_vs_Pakistan_523735.csv',
#  'Zimbabwe_vs_Pakistan_523736.csv',
#  'Zimbabwe_vs_Pakistan_659545.csv',
#  'Zimbabwe_vs_Pakistan_659547.csv',
#  'Zimbabwe_vs_Pakistan_919603.csv',
#  'Zimbabwe_vs_Pakistan_919605.csv']

# %%
def contact_match_files(csvs_list):
    firstFile = pd.read_csv(csvs_list[0])
    firstFile['match_type_number'] = csvs_list[0].split('_')[-1].replace('.csv', '')
    for i in range(1, len(csvs_list)):
        df = pd.read_csv(csvs_list[i])
        df['match_type_number'] = csvs_list[i].split('_')[-1].replace('.csv', '')
        firstFile = pd.concat([firstFile, df])
    
    return firstFile

# %% [markdown]
# # All T20 mathces innings information have be merged in a Single CSV file

# %%
concat_File = contact_match_files(csvs_list)

# %%
concat_File.to_csv('Pakistan_T20_Matches_Information.csv', index=False)

# %%
Pakistani_T20_Matches = pd.read_csv('Pakistan_T20_Matches_Information.csv')

# %%
Pakistani_T20_Matches
# Out:
#            Team  Over         Batter        Bowler    Non_Striker  \
# 0      Pakistan     0     Babar Azam      MA Starc   Fakhar Zaman
# 1      Pakistan     0     Babar Azam      MA Starc   Fakhar Zaman
# 2      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# 3      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# 4      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# ...         ...   ...            ...           ...            ...
# 56229  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56230  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56231  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56232  Pakistan    18   Shoaib Malik  B Muzarabani  Sarfraz Ahmed
# 56233  Pakistan    19  Sarfraz Ahmed      CB Mpofu   Shoaib Malik
#
#        Runs_Batter  Runs_Extras  Runs_Total  Wickets fielder_name kind  \
# 0                0            0           0        0          NaN  NaN
# 1                1            0           1        0          NaN  NaN
# 2                0            0           0        0          NaN  NaN
# 3                0            0           0        0          NaN  NaN
# 4                2            0           2        0          NaN  NaN
# ...            ...          ...         ...      ...          ...  ...
# 56229            2            0           2        0          NaN  NaN
# 56230            4            0           4        0          NaN  NaN
# 56231            1            0           1        0          NaN  NaN
# 56232            0            0           0        0          NaN  NaN
# 56233            4            0           4        0          NaN  NaN
#
#       player_out  match_type_number
# 0            NaN               1002
# 1            NaN               1002
# 2            NaN               1002
# 3            NaN               1002
# 4            NaN               1002
# ...          ...                ...
# 56229        NaN                685
# 56230        NaN                685
# 56231        NaN                685
# 56232        NaN                685
# 56233        NaN                685
#
# [56234 rows x 13 columns]

# %%
Pakistani_T20_Matches
# Out:
#            Team  Over         Batter        Bowler    Non_Striker  \
# 0      Pakistan     0     Babar Azam      MA Starc   Fakhar Zaman
# 1      Pakistan     0     Babar Azam      MA Starc   Fakhar Zaman
# 2      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# 3      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# 4      Pakistan     0   Fakhar Zaman      MA Starc     Babar Azam
# ...         ...   ...            ...           ...            ...
# 56229  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56230  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56231  Pakistan    18  Sarfraz Ahmed  B Muzarabani   Shoaib Malik
# 56232  Pakistan    18   Shoaib Malik  B Muzarabani  Sarfraz Ahmed
# 56233  Pakistan    19  Sarfraz Ahmed      CB Mpofu   Shoaib Malik
#
#        Runs_Batter  Runs_Extras  Runs_Total  Wickets fielder_name kind  \
# 0                0            0           0        0          NaN  NaN
# 1                1            0           1        0          NaN  NaN
# 2                0            0           0        0          NaN  NaN
# 3                0            0           0        0          NaN  NaN
# 4                2            0           2        0          NaN  NaN
# ...            ...          ...         ...      ...          ...  ...
# 56229            2            0           2        0          NaN  NaN
# 56230            4            0           4        0          NaN  NaN
# 56231            1            0           1        0          NaN  NaN
# 56232            0            0           0        0          NaN  NaN
# 56233            4            0           4        0          NaN  NaN
#
#       player_out  match_type_number
# 0            NaN               1002
# 1            NaN               1002
# 2            NaN               1002
# 3            NaN               1002
# 4            NaN               1002
# ...          ...                ...
# 56229        NaN                685
# 56230        NaN                685
# 56231        NaN                685
# 56232        NaN                685
# 56233        NaN                685
#
# [56234 rows x 13 columns]

# %%
match = pd.DataFrame(match_information)
players = pd.DataFrame(players_infomation)

# %%
match.to_csv('match_info.csv', index=False)
players.to_csv('Player_name.csv', index=False)
